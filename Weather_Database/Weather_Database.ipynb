# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import json
import time

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates

# %%
# Nearest cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city = cities[0]
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

# Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | pahrump
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | sitka
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | kenai
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | umm kaddadah
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | evensk
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | lazo
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | roald
# Processing Record 26 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 1 | teguise
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | jahrom
# City not found. Skipping...
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | hualmay
# Processing Record 33 of Set 1 | razole
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | kupang
# Processing Record 36 of Set 1 | thinadhoo
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | luanda
# Processing Record 40 of Set 1 | asosa
# Processing Record 41 of Set 1 | ewing
# Processing Record 42 of Set 1 | boende
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | sironj
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 49 of Set 1 | broome
# Processing Record 50 of Set 1 | north bend
# Processing Record 1 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | palana
# Processing Record 5 of Set 2 | nelson bay
# Processing Record 6 of Set 2 | maues
# Processing Record 7 of Set 2 | ormara
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | baiyin
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | kruisfontein
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | waingapu
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | concepcion del oro
# Processing Record 19 of Set 2 | alamos
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | aklavik
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | tomohon
# Processing Record 25 of Set 2 | vostok
# Processing Record 26 of Set 2 | omsukchan
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | sao joao da barra
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | cayenne
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | bahia honda
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | leningradskiy
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | orange cove
# Processing Record 42 of Set 2 | lagoa
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | amposta
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 2 | zaysan
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | cockburn town
# Processing Record 1 of Set 3 | ratnagiri
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | yuma
# Processing Record 8 of Set 3 | imeni poliny osipenko
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | lundazi
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | birjand
# Processing Record 14 of Set 3 | adrar
# Processing Record 15 of Set 3 | kamarion
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | puerto baquerizo moreno
# Processing Record 18 of Set 3 | codajas
# Processing Record 19 of Set 3 | mayo
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | cesme
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 24 of Set 3 | kalabo
# Processing Record 25 of Set 3 | santa fe
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | la rioja
# Processing Record 28 of Set 3 | puerto carreno
# Processing Record 29 of Set 3 | jalu
# Processing Record 30 of Set 3 | eresos
# Processing Record 31 of Set 3 | atar
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | ancud
# Processing Record 34 of Set 3 | aksu
# Processing Record 35 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | krasnyy chikoy
# Processing Record 38 of Set 3 | washington
# Processing Record 39 of Set 3 | beira
# Processing Record 40 of Set 3 | saint-augustin
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | libourne
# Processing Record 46 of Set 3 | ixtapa
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | burewala
# Processing Record 49 of Set 3 | abonnema
# Processing Record 50 of Set 3 | carbonia
# Processing Record 1 of Set 4 | chardara
# Processing Record 2 of Set 4 | sinnamary
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | pachino
# Processing Record 5 of Set 4 | portland
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | lipovtsy
# Processing Record 12 of Set 4 | ulladulla
# Processing Record 13 of Set 4 | saint-joseph
# Processing Record 14 of Set 4 | tahta
# Processing Record 15 of Set 4 | honningsvag
# Processing Record 16 of Set 4 | tarija
# Processing Record 17 of Set 4 | atbasar
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | avarua
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | nizhniy baskunchak
# Processing Record 25 of Set 4 | gat
# Processing Record 26 of Set 4 | camargo
# Processing Record 27 of Set 4 | morehead
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | turbo
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | gasa
# Processing Record 32 of Set 4 | changping
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | kihei
# Processing Record 35 of Set 4 | tual
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | san vicente
# Processing Record 39 of Set 4 | dickinson
# Processing Record 40 of Set 4 | manbij
# Processing Record 41 of Set 4 | rincon
# Processing Record 42 of Set 4 | birao
# Processing Record 43 of Set 4 | lexington
# Processing Record 44 of Set 4 | szczecinek
# Processing Record 45 of Set 4 | siilinjarvi
# Processing Record 46 of Set 4 | damaturu
# Processing Record 47 of Set 4 | krasnoselkup
# Processing Record 48 of Set 4 | porto novo
# Processing Record 49 of Set 4 | beloha
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | cleethorpes
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | segezha
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | svirstroy
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | lososina
# Processing Record 8 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | mikuni
# Processing Record 12 of Set 5 | yokadouma
# Processing Record 13 of Set 5 | bara
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | santa luzia
# Processing Record 16 of Set 5 | san miguel de cauri
# Processing Record 17 of Set 5 | gniezno
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | ouadda
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | vila do maio
# Processing Record 23 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | divnomorskoye
# Processing Record 26 of Set 5 | surgut
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | saint-philippe
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | kyren
# Processing Record 32 of Set 5 | tarko-sale
# Processing Record 33 of Set 5 | camana
# Processing Record 34 of Set 5 | douglas
# Processing Record 35 of Set 5 | kununurra
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | antigonish
# Processing Record 38 of Set 5 | ambon
# Processing Record 39 of Set 5 | vostochnyy
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | egvekinot
# Processing Record 42 of Set 5 | araouane
# Processing Record 43 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 5 | pedro juan caballero
# Processing Record 45 of Set 5 | saint-raymond
# Processing Record 46 of Set 5 | namie
# Processing Record 47 of Set 5 | parker
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | mwene-ditu
# Processing Record 50 of Set 5 | ulaanbaatar
# Processing Record 1 of Set 6 | verkhoyansk
# Processing Record 2 of Set 6 | thetford mines
# Processing Record 3 of Set 6 | leonidion
# City not found. Skipping...
# Processing Record 4 of Set 6 | sungaipenuh
# Processing Record 5 of Set 6 | batemans bay
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 9 of Set 6 | antalaha
# Processing Record 10 of Set 6 | matay
# Processing Record 11 of Set 6 | fort pierce
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | bahia blanca
# Processing Record 14 of Set 6 | sokyryany
# Processing Record 15 of Set 6 | srednekolymsk
# Processing Record 16 of Set 6 | petrolina
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | susehri
# Processing Record 19 of Set 6 | asau
# Processing Record 20 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | solnechnyy
# Processing Record 22 of Set 6 | herat
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | imuris
# Processing Record 25 of Set 6 | dicabisagan
# Processing Record 26 of Set 6 | pavlodar
# Processing Record 27 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 6 | raudeberg
# Processing Record 29 of Set 6 | lakatoro
# Processing Record 30 of Set 6 | fukue
# Processing Record 31 of Set 6 | kargasok
# Processing Record 32 of Set 6 | dabat
# Processing Record 33 of Set 6 | tocopilla
# Processing Record 34 of Set 6 | puerto quijarro
# Processing Record 35 of Set 6 | mantua
# Processing Record 36 of Set 6 | mecca
# Processing Record 37 of Set 6 | turukhansk
# Processing Record 38 of Set 6 | paamiut
# Processing Record 39 of Set 6 | vao
# Processing Record 40 of Set 6 | shetpe
# Processing Record 41 of Set 6 | yeppoon
# Processing Record 42 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 6 | solton
# Processing Record 44 of Set 6 | shimanovsk
# Processing Record 45 of Set 6 | san martin
# Processing Record 46 of Set 6 | husavik
# Processing Record 47 of Set 6 | sumbe
# Processing Record 48 of Set 6 | noyabrsk
# Processing Record 49 of Set 6 | lokosovo
# Processing Record 50 of Set 6 | aykhal
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | longyearbyen
# Processing Record 3 of Set 7 | novyy urengoy
# Processing Record 4 of Set 7 | bokaa
# Processing Record 5 of Set 7 | horki
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | barcelos
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | camacha
# Processing Record 10 of Set 7 | leshukonskoye
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | port-cartier
# Processing Record 13 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 7 | salgar
# Processing Record 15 of Set 7 | wanaka
# Processing Record 16 of Set 7 | baruun-urt
# Processing Record 17 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 7 | sur
# Processing Record 19 of Set 7 | ambanja
# Processing Record 20 of Set 7 | bilma
# Processing Record 21 of Set 7 | kralendijk
# Processing Record 22 of Set 7 | meadow lake
# Processing Record 23 of Set 7 | malanje
# Processing Record 24 of Set 7 | moron
# Processing Record 25 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 7 | san rafael
# Processing Record 27 of Set 7 | tura
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | beringovskiy
# Processing Record 32 of Set 7 | ilebo
# Processing Record 33 of Set 7 | yangliuqing
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | college
# Processing Record 36 of Set 7 | ulaangom
# Processing Record 37 of Set 7 | ucluelet
# Processing Record 38 of Set 7 | boa vista
# Processing Record 39 of Set 7 | reinosa
# Processing Record 40 of Set 7 | sovetskiy
# Processing Record 41 of Set 7 | takoradi
# Processing Record 42 of Set 7 | pineville
# Processing Record 43 of Set 7 | raga
# Processing Record 44 of Set 7 | manokwari
# Processing Record 45 of Set 7 | zaragoza
# Processing Record 46 of Set 7 | kongoussi
# Processing Record 47 of Set 7 | xam nua
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | namibe
# Processing Record 1 of Set 8 | loiza
# Processing Record 2 of Set 8 | inhambane
# Processing Record 3 of Set 8 | maceio
# Processing Record 4 of Set 8 | enshi
# Processing Record 5 of Set 8 | santa rosa
# Processing Record 6 of Set 8 | bealanana
# Processing Record 7 of Set 8 | poya
# Processing Record 8 of Set 8 | ranghulu
# Processing Record 9 of Set 8 | venezuela
# Processing Record 10 of Set 8 | haines junction
# Processing Record 11 of Set 8 | shitanjing
# Processing Record 12 of Set 8 | naples
# Processing Record 13 of Set 8 | tiksi
# Processing Record 14 of Set 8 | najran
# Processing Record 15 of Set 8 | tungi
# Processing Record 16 of Set 8 | hofn
# Processing Record 17 of Set 8 | yatou
# Processing Record 18 of Set 8 | bambous virieux
# Processing Record 19 of Set 8 | bjerkvik
# Processing Record 20 of Set 8 | bayanday
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | iquique
# Processing Record 23 of Set 8 | agadez
# Processing Record 24 of Set 8 | gazojak
# Processing Record 25 of Set 8 | indian head
# Processing Record 26 of Set 8 | berlevag
# Processing Record 27 of Set 8 | dieppe
# Processing Record 28 of Set 8 | kamaishi
# Processing Record 29 of Set 8 | neftcala
# Processing Record 30 of Set 8 | minsk
# Processing Record 31 of Set 8 | kolosovka
# Processing Record 32 of Set 8 | ambulu
# Processing Record 33 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 8 | yurimaguas
# Processing Record 35 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 36 of Set 8 | clyde river
# Processing Record 37 of Set 8 | indramayu
# Processing Record 38 of Set 8 | marawi
# Processing Record 39 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | buraydah
# Processing Record 41 of Set 8 | airai
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | lahaina
# Processing Record 44 of Set 8 | hobyo
# Processing Record 45 of Set 8 | sume
# Processing Record 46 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 8 | zinder
# Processing Record 48 of Set 8 | garowe
# Processing Record 49 of Set 8 | sibu
# Processing Record 50 of Set 8 | nizwa
# Processing Record 1 of Set 9 | parrita
# Processing Record 2 of Set 9 | aksarka
# Processing Record 3 of Set 9 | tres arroyos
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | gamba
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | lagos
# Processing Record 8 of Set 9 | radom
# Processing Record 9 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 9 | mantsala
# Processing Record 11 of Set 9 | ternate
# Processing Record 12 of Set 9 | visby
# Processing Record 13 of Set 9 | lazaro cardenas
# Processing Record 14 of Set 9 | ahipara
# Processing Record 15 of Set 9 | lichinga
# Processing Record 16 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 17 of Set 9 | sambava
# Processing Record 18 of Set 9 | manitouwadge
# Processing Record 19 of Set 9 | japura
# Processing Record 20 of Set 9 | nouakchott
# Processing Record 21 of Set 9 | uinskoye
# Processing Record 22 of Set 9 | sayyan
# Processing Record 23 of Set 9 | kanashevo
# Processing Record 24 of Set 9 | ye
# City not found. Skipping...
# Processing Record 25 of Set 9 | ailigandi
# Processing Record 26 of Set 9 | durusu
# Processing Record 27 of Set 9 | daru
# Processing Record 28 of Set 9 | madang
# Processing Record 29 of Set 9 | panguna
# Processing Record 30 of Set 9 | liku
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | yola
# Processing Record 33 of Set 9 | mago
# Processing Record 34 of Set 9 | olinda
# Processing Record 35 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 36 of Set 9 | marzuq
# Processing Record 37 of Set 9 | jining
# Processing Record 38 of Set 9 | boddam
# Processing Record 39 of Set 9 | wanlaweyn
# Processing Record 40 of Set 9 | sobolevo
# Processing Record 41 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 42 of Set 9 | gaoua
# Processing Record 43 of Set 9 | konongo
# Processing Record 44 of Set 9 | memaliaj
# Processing Record 45 of Set 9 | pevek
# Processing Record 46 of Set 9 | cedro
# Processing Record 47 of Set 9 | villefranche-sur-saone
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | acarau
# Processing Record 50 of Set 9 | cedral
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | santiago de cao
# Processing Record 3 of Set 10 | fairbanks
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 10 | morros
# Processing Record 8 of Set 10 | iquitos
# Processing Record 9 of Set 10 | zhangjiakou
# Processing Record 10 of Set 10 | maxixe
# Processing Record 11 of Set 10 | la ronge
# Processing Record 12 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 13 of Set 10 | bow island
# Processing Record 14 of Set 10 | dakar
# Processing Record 15 of Set 10 | fort nelson
# Processing Record 16 of Set 10 | donskoy
# Processing Record 17 of Set 10 | saint anthony
# Processing Record 18 of Set 10 | de-kastri
# Processing Record 19 of Set 10 | manggar
# Processing Record 20 of Set 10 | general roca
# Processing Record 21 of Set 10 | juba
# Processing Record 22 of Set 10 | aswan
# Processing Record 23 of Set 10 | lyuban
# Processing Record 24 of Set 10 | deming
# Processing Record 25 of Set 10 | katwijk
# Processing Record 26 of Set 10 | balkanabat
# Processing Record 27 of Set 10 | avera
# Processing Record 28 of Set 10 | yamada
# Processing Record 29 of Set 10 | sept-iles
# Processing Record 30 of Set 10 | sola
# Processing Record 31 of Set 10 | pakdasht
# Processing Record 32 of Set 10 | batagay-alyta
# Processing Record 33 of Set 10 | atwater
# Processing Record 34 of Set 10 | hamilton
# Processing Record 35 of Set 10 | erzin
# Processing Record 36 of Set 10 | kashi
# Processing Record 37 of Set 10 | puerto del rosario
# Processing Record 38 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 39 of Set 10 | alexandria
# Processing Record 40 of Set 10 | nizhneudinsk
# Processing Record 41 of Set 10 | geraldton
# Processing Record 42 of Set 10 | dire dawa
# Processing Record 43 of Set 10 | chute-aux-outardes
# Processing Record 44 of Set 10 | nome
# Processing Record 45 of Set 10 | kaitangata
# Processing Record 46 of Set 10 | vinh long
# Processing Record 47 of Set 10 | sosnovskiy
# City not found. Skipping...
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | caravelas
# Processing Record 50 of Set 10 | hanzhong
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | puerto lumbreras
# Processing Record 3 of Set 11 | agadir
# Processing Record 4 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 11 | quatre cocos
# Processing Record 6 of Set 11 | xuddur
# Processing Record 7 of Set 11 | rio grande
# Processing Record 8 of Set 11 | pagondas
# City not found. Skipping...
# Processing Record 9 of Set 11 | phan thiet
# Processing Record 10 of Set 11 | zwedru
# Processing Record 11 of Set 11 | baykit
# Processing Record 12 of Set 11 | staryy nadym
# Processing Record 13 of Set 11 | erice
# Processing Record 14 of Set 11 | jiazi
# Processing Record 15 of Set 11 | matamoros
# Processing Record 16 of Set 11 | navrongo
# Processing Record 17 of Set 11 | shilovo
# Processing Record 18 of Set 11 | tazmalt
# Processing Record 19 of Set 11 | cap malheureux
# Processing Record 20 of Set 11 | wundanyi
# Processing Record 21 of Set 11 | lompoc
# Processing Record 22 of Set 11 | chino valley
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | aleksandrov gay
# Processing Record 25 of Set 11 | freeport
# Processing Record 26 of Set 11 | nkan
# Processing Record 27 of Set 11 | ayan
# Processing Record 28 of Set 11 | halifax
# Processing Record 29 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 30 of Set 11 | vila franca do campo
# Processing Record 31 of Set 11 | ramsar
# Processing Record 32 of Set 11 | stuttgart
# Processing Record 33 of Set 11 | pak phanang
# Processing Record 34 of Set 11 | holme
# Processing Record 35 of Set 11 | reconquista
# Processing Record 36 of Set 11 | ust-maya
# Processing Record 37 of Set 11 | tukums
# Processing Record 38 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 39 of Set 11 | mogoytuy
# Processing Record 40 of Set 11 | souillac
# Processing Record 41 of Set 11 | katima mulilo
# Processing Record 42 of Set 11 | sao miguel do araguaia
# Processing Record 43 of Set 11 | san carlos
# Processing Record 44 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 11 | sembe
# Processing Record 46 of Set 11 | dois vizinhos
# Processing Record 47 of Set 11 | krutaya gorka
# Processing Record 48 of Set 11 | kirkwall
# Processing Record 49 of Set 11 | yantal
# Processing Record 50 of Set 11 | hambantota
# Processing Record 1 of Set 12 | merauke
# Processing Record 2 of Set 12 | cajati
# Processing Record 3 of Set 12 | horsham
# Processing Record 4 of Set 12 | vardo
# Processing Record 5 of Set 12 | bacalar
# Processing Record 6 of Set 12 | huilong
# Processing Record 7 of Set 12 | verkhnevilyuysk
# Processing Record 8 of Set 12 | lavrentiya
# Processing Record 9 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 12 | challapata
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | palmer
# Processing Record 13 of Set 12 | mastic beach
# Processing Record 14 of Set 12 | vega de alatorre
# Processing Record 15 of Set 12 | sorland
# Processing Record 16 of Set 12 | belle fourche
# Processing Record 17 of Set 12 | prince rupert
# Processing Record 18 of Set 12 | addi ugri
# City not found. Skipping...
# Processing Record 19 of Set 12 | portel
# Processing Record 20 of Set 12 | chapleau
# Processing Record 21 of Set 12 | mbouda
# Processing Record 22 of Set 12 | bulawayo
# Processing Record 23 of Set 12 | gornopravdinsk
# Processing Record 24 of Set 12 | vuktyl
# Processing Record 25 of Set 12 | riyadh
# Processing Record 26 of Set 12 | falkenberg
# Processing Record 27 of Set 12 | svetlogorsk
# Processing Record 28 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 12 | usinsk
# Processing Record 30 of Set 12 | luau
# Processing Record 31 of Set 12 | kampong chhnang
# Processing Record 32 of Set 12 | port hedland
# Processing Record 33 of Set 12 | dalvik
# Processing Record 34 of Set 12 | turriff
# Processing Record 35 of Set 12 | zhigansk
# Processing Record 36 of Set 12 | paita
# Processing Record 37 of Set 12 | ahuimanu
# Processing Record 38 of Set 12 | valparaiso
# Processing Record 39 of Set 12 | pandamatenga
# Processing Record 40 of Set 12 | yusva
# City not found. Skipping...
# Processing Record 41 of Set 12 | ola
# Processing Record 42 of Set 12 | tekeli
# Processing Record 43 of Set 12 | pemangkat
# Processing Record 44 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 12 | ayagoz
# Processing Record 46 of Set 12 | lata
# Processing Record 47 of Set 12 | mukhen
# Processing Record 48 of Set 12 | harfleur
# Processing Record 49 of Set 12 | mpika
# Processing Record 50 of Set 12 | lembeni
# Processing Record 1 of Set 13 | inuvik
# Processing Record 2 of Set 13 | dutlwe
# Processing Record 3 of Set 13 | bac lieu
# Processing Record 4 of Set 13 | caxito
# Processing Record 5 of Set 13 | chifeng
# Processing Record 6 of Set 13 | alegrete
# Processing Record 7 of Set 13 | vallenar
# Processing Record 8 of Set 13 | kodinsk
# Processing Record 9 of Set 13 | flin flon
# Processing Record 10 of Set 13 | qianan
# Processing Record 11 of Set 13 | olafsvik
# Processing Record 12 of Set 13 | volary
# Processing Record 13 of Set 13 | aquidauana
# Processing Record 14 of Set 13 | koungou
# Processing Record 15 of Set 13 | snasa
# Processing Record 16 of Set 13 | otane
# Processing Record 17 of Set 13 | chicama
# Processing Record 18 of Set 13 | elizabeth city
# Processing Record 19 of Set 13 | arlit
# Processing Record 20 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 13 | kathu
# Processing Record 22 of Set 13 | la uvita
# Processing Record 23 of Set 13 | north myrtle beach
# Processing Record 24 of Set 13 | nago
# Processing Record 25 of Set 13 | bludenz
# Processing Record 26 of Set 13 | along
# Processing Record 27 of Set 13 | mackay
# Processing Record 28 of Set 13 | eyemouth
# Processing Record 29 of Set 13 | byron bay
# Processing Record 30 of Set 13 | eureka
# Processing Record 31 of Set 13 | totness
# Processing Record 32 of Set 13 | belaya gora
# Processing Record 33 of Set 13 | siwana
# Processing Record 34 of Set 13 | pierre
# Processing Record 35 of Set 13 | calvinia
# Processing Record 36 of Set 13 | yerofey pavlovich
# Processing Record 37 of Set 13 | tutoia
# Processing Record 38 of Set 13 | novokruchininskiy
# Processing Record 39 of Set 13 | batagay
# Processing Record 40 of Set 13 | florence
# Processing Record 41 of Set 13 | coihaique
# Processing Record 42 of Set 13 | chiredzi
# Processing Record 43 of Set 13 | port moresby
# Processing Record 44 of Set 13 | luzhou
# Processing Record 45 of Set 13 | great falls
# Processing Record 46 of Set 13 | sergeyevka
# Processing Record 47 of Set 13 | les cayes
# Processing Record 48 of Set 13 | chengmai
# City not found. Skipping...
# Processing Record 49 of Set 13 | umea
# Processing Record 50 of Set 13 | naze
# Processing Record 1 of Set 14 | thabazimbi
# Processing Record 2 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 14 | mizdah
# Processing Record 4 of Set 14 | georgiyevka
# Processing Record 5 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 6 of Set 14 | illintsi
# Processing Record 7 of Set 14 | pushkino
# Processing Record 8 of Set 14 | kabanjahe
# Processing Record 9 of Set 14 | mount gambier
# Processing Record 10 of Set 14 | zyryanka
# Processing Record 11 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 14 | kathmandu
# Processing Record 13 of Set 14 | sarmellek
# Processing Record 14 of Set 14 | taoudenni
# Processing Record 15 of Set 14 | margate
# Processing Record 16 of Set 14 | bozeman
# Processing Record 17 of Set 14 | salinopolis
# Processing Record 18 of Set 14 | hay river
# Processing Record 19 of Set 14 | maroantsetra
# Processing Record 20 of Set 14 | lenoir city
# Processing Record 21 of Set 14 | montanha
# Processing Record 22 of Set 14 | nerang
# Processing Record 23 of Set 14 | guerrero negro
# Processing Record 24 of Set 14 | isla aguada
# Processing Record 25 of Set 14 | leskovik
# Processing Record 26 of Set 14 | vertientes
# Processing Record 27 of Set 14 | union
# Processing Record 28 of Set 14 | abashiri
# Processing Record 29 of Set 14 | khash
# Processing Record 30 of Set 14 | mezhdurechensk
# Processing Record 31 of Set 14 | srandakan
# Processing Record 32 of Set 14 | lloydminster
# Processing Record 33 of Set 14 | marsa matruh
# Processing Record 34 of Set 14 | sakaiminato
# Processing Record 35 of Set 14 | padang
# Processing Record 36 of Set 14 | kifri
# Processing Record 37 of Set 14 | kichmengskiy gorodok
# Processing Record 38 of Set 14 | la paz
# Processing Record 39 of Set 14 | cedarburg
# Processing Record 40 of Set 14 | oriximina
# Processing Record 41 of Set 14 | haicheng
# Processing Record 42 of Set 14 | yumen
# Processing Record 43 of Set 14 | sokoni
# Processing Record 44 of Set 14 | ayios matthaios
# City not found. Skipping...
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | ladovskaya balka
# Processing Record 47 of Set 14 | illela
# Processing Record 48 of Set 14 | neiba
# Processing Record 49 of Set 14 | kingman
# Processing Record 50 of Set 14 | vikulovo
# Processing Record 1 of Set 15 | kieta
# Processing Record 2 of Set 15 | brigantine
# Processing Record 3 of Set 15 | qasigiannguit
# Processing Record 4 of Set 15 | sokoto
# Processing Record 5 of Set 15 | waterford
# Processing Record 6 of Set 15 | barguzin
# Processing Record 7 of Set 15 | los llanos de aridane
# Processing Record 8 of Set 15 | qaqortoq
# Processing Record 9 of Set 15 | nenjiang
# Processing Record 10 of Set 15 | nuuk
# Processing Record 11 of Set 15 | nankana sahib
# Processing Record 12 of Set 15 | dembi dolo
# Processing Record 13 of Set 15 | ozernovskiy
# Processing Record 14 of Set 15 | pocoes
# Processing Record 15 of Set 15 | champerico
# Processing Record 16 of Set 15 | ust-kuyga
# Processing Record 17 of Set 15 | kozhevnikovo
# Processing Record 18 of Set 15 | chara
# Processing Record 19 of Set 15 | alyangula
# Processing Record 20 of Set 15 | derzhavinsk
# Processing Record 21 of Set 15 | taunggyi
# Processing Record 22 of Set 15 | kuantan
# Processing Record 23 of Set 15 | kjollefjord
# Processing Record 24 of Set 15 | barra
# Processing Record 25 of Set 15 | fare
# Processing Record 26 of Set 15 | djibo
# Processing Record 27 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 15 | mujiayingzi
# Processing Record 29 of Set 15 | mumford
# Processing Record 30 of Set 15 | comodoro rivadavia
# Processing Record 31 of Set 15 | namatanai
# Processing Record 32 of Set 15 | rujewa
# Processing Record 33 of Set 15 | saint-georges
# Processing Record 34 of Set 15 | duz
# City not found. Skipping...
# Processing Record 35 of Set 15 | winslow
# Processing Record 36 of Set 15 | lasa
# Processing Record 37 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 15 | atambua
# Processing Record 39 of Set 15 | tessalit
# Processing Record 40 of Set 15 | vetluzhskiy
# Processing Record 41 of Set 15 | saint-francois
# Processing Record 42 of Set 15 | carutapera
# Processing Record 43 of Set 15 | lufilufi
# Processing Record 44 of Set 15 | tete
# Processing Record 45 of Set 15 | kemijarvi
# Processing Record 46 of Set 15 | puerto leguizamo
# Processing Record 47 of Set 15 | teguldet
# Processing Record 48 of Set 15 | jutai
# Processing Record 49 of Set 15 | dao
# Processing Record 50 of Set 15 | roma
# Processing Record 1 of Set 16 | mucurapo
# Processing Record 2 of Set 16 | sun city west
# Processing Record 3 of Set 16 | korhogo
# Processing Record 4 of Set 16 | balikpapan
# Processing Record 5 of Set 16 | vytegra
# Processing Record 6 of Set 16 | san fernando
# Processing Record 7 of Set 16 | stirling
# Processing Record 8 of Set 16 | maragogi
# Processing Record 9 of Set 16 | burica
# City not found. Skipping...
# Processing Record 10 of Set 16 | portree
# Processing Record 11 of Set 16 | oneonta
# Processing Record 12 of Set 16 | yahotyn
# Processing Record 13 of Set 16 | vestbygda
# City not found. Skipping...
# Processing Record 14 of Set 16 | aszalo
# Processing Record 15 of Set 16 | joshimath
# Processing Record 16 of Set 16 | goma
# Processing Record 17 of Set 16 | conde
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Severo-Kurilsk  50.6789  156.1250     45.99        85         100
# 1           Mataura -46.1927  168.8643     43.48        86          48
# 2            Faanui -16.4833 -151.7500     78.84        74          38
# 3            Albany  42.6001  -73.9662     67.39        71          27
# 4           Pahrump  36.2083 -115.9839    103.24        10          98
# ..              ...      ...       ...       ...       ...         ...
# 697         Yahotyn  50.2798   31.7625     61.09        81          37
# 698          Aszalo  48.2167   20.9667     62.71        85          39
# 699       Joshimath  30.5667   79.5667     64.71        52          44
# 700            Goma  -1.6792   29.2228     62.13        91          96
# 701           Conde  -7.2597  -34.9075     74.66       100           0
#
#      Wind Speed Country       Description
# 0          5.28      RU   overcast clouds
# 1          5.21      NZ  scattered clouds
# 2          5.44      PF     moderate rain
# 3         12.33      US  scattered clouds
# 4         10.00      US   overcast clouds
# ..          ...     ...               ...
# 697        7.38      UA  scattered clouds
# 698        4.29      HU  scattered clouds
# 699        5.41      IN  scattered clouds
# 700        1.83      CD        light rain
# 701        3.44      BR         clear sky
#
# [702 rows x 9 columns]

# %%
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk  50.6789  156.1250     45.99        85         100
# 1         Mataura -46.1927  168.8643     43.48        86          48
# 2          Faanui -16.4833 -151.7500     78.84        74          38
# 3          Albany  42.6001  -73.9662     67.39        71          27
# 4         Pahrump  36.2083 -115.9839    103.24        10          98
# 5       Jamestown  42.0970  -79.2353     65.01        61         100
# 6       Carnarvon -24.8667  113.6333     68.54        83          34
# 7           Kapaa  22.0752 -159.3190     82.47        69          20
# 8           Sitka  57.0531 -135.3300     60.69        48          75
# 9    Port Lincoln -34.7333  135.8667     56.08        73         100
#
#    Wind Speed Country       Description
# 0        5.28      RU   overcast clouds
# 1        5.21      NZ  scattered clouds
# 2        5.44      PF     moderate rain
# 3       12.33      US  scattered clouds
# 4       10.00      US   overcast clouds
# 5       13.80      US   overcast clouds
# 6       12.24      AU  scattered clouds
# 7       10.36      US        few clouds
# 8       10.36      US     broken clouds
# 9        8.25      AU   overcast clouds
